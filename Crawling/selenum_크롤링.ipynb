# %%
# !apt-get update > /dev/null 2>&1
# !pip install selenium > /dev/null 2>&1
# !apt install chromium-chromedriver > /dev/null 2>&1

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.common.by import By

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless') #화면 없이 
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %%
url ='https://www.google.co.kr/' 
driver.get(url)

# %%
search_box = driver.find_element(by=By.NAME, value='q')
search_box.send_keys('ChromeDriver')
search_box.send_keys(Keys.ENTER)
time.sleep(2)

# %%
divs = driver.find_elements(By.CSS_SELECTOR, '#search .g')
len(divs)
# Out:
# 12

# %%
div = divs[0]

# %%
title = div.find_element(By.CSS_SELECTOR, '.LC20lb.MBeuO.DKV0Md').text
title
# Out:
# 'WebDriver for Chrome - Downloads'

# %%
contents = div.find_element(By.CSS_SELECTOR,'.VwiC3b.yXK7lf.MUxGbd').text.strip()
contents
# Out:
# 'If you are using Chrome version 107, please download ChromeDriver 107.0.5304.62. For older version of Chrome, please see below for the version of ...'

# %%
lines = []
for div in divs:
    try:
        title = div.find_element(By.CSS_SELECTOR, '.LC20lb.MBeuO.DKV0Md').text
        contents = div.find_element(By.CSS_SELECTOR,'.VwiC3b.yXK7lf.MUxGbd').text.strip()
    except:
        continue
    lines.append([title, contents])

# %%
df=pd.DataFrame(lines, columns =['title', 'contents'])
df
# Out:
#                                                title  \
# 0                   WebDriver for Chrome - Downloads
# 1   ChromeDriver · SeleniumHQ/selenium Wiki - GitHub
# 2                                      Chrome driver
# 3                 Install browser drivers - Selenium
# 4                                 chromedriver - npm
# 5  chrome/test/chromedriver - chromium/src - Git ...
# 6  Selenium.WebDriver.ChromeDriver 109.0.5414.740...
# 7             Override ChromeDriver Version - Provar
#
#                                             contents
# 0  If you are using Chrome version 107, please do...
# 1  Dec 26, 2021 — A browser automation framework ...
# 2  Index of / ; [DIR], 2.0, - ; [DIR], 2.1, - ; [...
# 3  Dec 1, 2022 — Please see https://chromedriver....
# 4  An NPM wrapper for Selenium ChromeDriver. Buil...
# 5  ChromeDriver is a standalone server which comm...
# 6  Install Chrome Driver (Win32, macOS, macOS arm...
# 7  Override ChromeDriver Version. In case you nee...
