# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.genie.co.kr/chart/top200'
header ={'User-Agent':'Mozila/5.0 (Windows NT 10.0: Win64: x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
import pandas as pd

# %%
trs = soup.find_all('tr')
len(trs)
# Out:
# 51

# %%
trs = soup.select('tr.list')
len(trs)
# Out:
# 50

# %%
#개발자 도구에서 가져올 수 있는 방법
trs=soup.select('#body-content > div.newest-list > div > table > tbody > tr')
len(trs)
# Out:
# 50

# %%
tr=trs[12]
tr

# %%
#rank
tr.select_one('.number').get_text()
# Out:
# '13\n                                        \n                                    \n1상승\n\n'

# %%
try:
    rank=int(tr.select_one('.number').get_text().split('\n')[0])
except:
    rank = 0
rank
# Out:
# 13

# %%
#제목
try: #일반적 노래
    title = tr.select_one('.title.ellipsis').string.split
except: #19금 노래
    title = tr.select_one('.title.ellipsis').get_text().split('\n')[-1].strip()
title
# Out:
# <function NavigableString.split(sep=None, maxsplit=-1)>

# %%
artist = tr.select_one('.artist.ellipsis').text.split
artist
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
album =tr.select_one('.albumtitle.ellipsis').text.split
album
# Out:
# <function NavigableString.split(sep=None, maxsplit=-1)>

# %% [markdown]
# 개별리스트로 가져오기

# %%
rank_list, title_list, artist_list, album_list =[],[],[],[]
for i, tr in enumerate(trs):
    rank=int(tr.select_one('.number').get_text().split('\n')[0])
    title = tr.select_one('.title.ellipsis').string.split
    artist = tr.select_one('.artist.ellipsis').text.split
    album =tr.select_one('.albumtitle.ellipsis').text.split
    rank_list.append(rank)
    rank_list.append(rank)
